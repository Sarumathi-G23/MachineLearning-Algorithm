# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv('/content/drive/MyDrive/i1.csv')

# %%
data2=pd.read_csv('/content/drive/MyDrive/i2.csv')

# %%
fi=data1.merge(data2,how='outer')#Outer vanthu dataset epadi iruthalum merge panum

# %%
fi
# Out:
#              Date            Timestamp  Invoice No.  \
# 0      2023-04-01  2023-04-01 13:16:03        23465
# 1      2023-04-01  2023-04-01 13:16:03        23465
# 2      2023-04-01  2023-04-01 13:16:03        23465
# 3      2023-04-01  2023-04-01 13:16:03        23465
# 4      2023-04-01  2023-04-01 13:16:03        23465
# ...           ...                  ...          ...
# 15616  2023-09-19  2023-09-19 22:03:44        28389
# 15617  2023-09-19  2023-09-19 22:03:44        28389
# 15618  2023-09-19  2023-09-19 22:03:44        28389
# 15619  2023-09-19  2023-09-19 22:03:44        28389
# 15620  2023-09-19  2023-09-19 22:03:44        28389
#
#                          Item Name  Price  Qty.  Sub Total  Discount    Tax  \
# 0              Babycorn Manchurian  160.0   1.0      160.0       0.0   8.00
# 1                Chicken Kati Roll  120.0   1.0      120.0       0.0   6.00
# 2             Paneer Butter Masala  150.0   2.0      300.0       0.0  15.00
# ...

# %%
fi.shape
# Out:
# (15621, 16)

# %%
fi.head
# Out:
# <bound method NDFrame.head of              Date            Timestamp  Invoice No.  \
# 0      2023-04-01  2023-04-01 13:16:03        23465
# 1      2023-04-01  2023-04-01 13:16:03        23465
# 2      2023-04-01  2023-04-01 13:16:03        23465
# 3      2023-04-01  2023-04-01 13:16:03        23465
# 4      2023-04-01  2023-04-01 13:16:03        23465
# ...           ...                  ...          ...
# 15616  2023-09-19  2023-09-19 22:03:44        28389
# 15617  2023-09-19  2023-09-19 22:03:44        28389
# 15618  2023-09-19  2023-09-19 22:03:44        28389
# 15619  2023-09-19  2023-09-19 22:03:44        28389
# 15620  2023-09-19  2023-09-19 22:03:44        28389
#
#                          Item Name  Price  Qty.  Sub Total  Discount    Tax  \
# 0              Babycorn Manchurian  160.0   1.0      160.0       0.0   8.00
# 1                Chicken Kati Roll  120.0   1.0      120.0       0.0   6.00
# 2             Paneer Butter Masala  150.0   2.0      300.0       0.0  15.00
# ...

# %%
fi.isnull().sum()
# Out:
# Date               0
# Timestamp          0
# Invoice No.        0
# Item Name          0
# Price              0
# Qty.               0
# Sub Total          0
# Discount           0
# Tax                0
# Final Total        0
# Table No.          8
# Server Name        0
# Covers             0
# Variation      15606
# Category           0
# HSN            15621
# dtype: int64

# %%
fi.info
# Out:
# <bound method DataFrame.info of              Date            Timestamp  Invoice No.  \
# 0      2023-04-01  2023-04-01 13:16:03        23465
# 1      2023-04-01  2023-04-01 13:16:03        23465
# 2      2023-04-01  2023-04-01 13:16:03        23465
# 3      2023-04-01  2023-04-01 13:16:03        23465
# 4      2023-04-01  2023-04-01 13:16:03        23465
# ...           ...                  ...          ...
# 15616  2023-09-19  2023-09-19 22:03:44        28389
# 15617  2023-09-19  2023-09-19 22:03:44        28389
# 15618  2023-09-19  2023-09-19 22:03:44        28389
# 15619  2023-09-19  2023-09-19 22:03:44        28389
# 15620  2023-09-19  2023-09-19 22:03:44        28389
#
#                          Item Name  Price  Qty.  Sub Total  Discount    Tax  \
# 0              Babycorn Manchurian  160.0   1.0      160.0       0.0   8.00
# 1                Chicken Kati Roll  120.0   1.0      120.0       0.0   6.00
# 2             Paneer Butter Masala  150.0   2.0      300.0       0.0  15.00
# ...

# %%
fi.describe()
# Out:
#         Invoice No.         Price          Qty.     Sub Total      Discount  \
# count  15621.000000  15621.000000  15621.000000  15621.000000  15621.000000
# mean   25989.963127    116.608988      1.338839    147.407080      1.262818
# std     1433.192998     63.663769      0.949814    210.127442      6.656396
# min    23465.000000     12.000000      1.000000     12.000000      0.000000
# 25%    24751.000000     50.000000      1.000000     80.000000      0.000000
# 50%    25980.000000    140.000000      1.000000    150.000000      0.000000
# 75%    27274.000000    160.000000      1.000000    170.000000      0.000000
# max    28389.000000    770.000000     28.000000  21560.000000    288.000000
#
#                 Tax   Final Total     Table No.   Covers  HSN
# count  15621.000000  15621.000000  15613.000000  15621.0  0.0
# mean       7.303668    153.447930     18.068340      0.0  NaN
# std       10.461474    219.678163     17.191377      0.0  NaN
# ...

# %%
fi["Invoice No."].unique()
# Out:
# array([23465, 23466, 23467, ..., 28387, 28388, 28389])

# %%
fi["Invoice No."].nunique() #number/count of unique value
# Out:
# 4925

# %%
fi["Final Total"].sum() #total revenue taking sum of any one of col
# Out:
# np.float64(2397010.12)

# %%
fi["Final Total"].sum()/fi["Invoice No."].nunique()#Averagee
# Out:
# np.float64(486.70256243654825)

# %%
fi.groupby("Invoice No.")#club all the similar invoice num

# %%
fi.groupby("Invoice No.")["Final Total"].sum().loc[28327]#calculating specific invoice
# Out:
# np.float64(1081.5)

# %%
#most fav item of restrautant by quantity wise
fi["Qty."].sum()
# Out:
# np.float64(20914.0)

# %%
fi.groupby("Item Name")["Qty."].sum()
# Out:
# Item Name
# 1 Indian Combo - Welcome Drink, Chicken Dum Biriyani, Onion Raita, Chicken Gravy, Boiled Egg, Chicke    29.0
# Aalu Gobi Masala                                                                                         3.0
# Aalu Mutter Masala                                                                                       1.0
# American Chopsey( Veg)                                                                                   1.0
# Baby Corn 65                                                                                            55.0
#                                                                                                         ...
# Vegetable Pepper Soup                                                                                   50.0
# Venila Milk Shake                                                                                       28.0
# ...

# %%
fi.groupby("Item Name")["Qty."].sum().sort_values(ascending=False).head(3) #to get top 3 item that sales in restau
# Out:
# Item Name
# Mineral Water                             1672.0
# Chicken Biriyani With Raitha And Gravy    1453.0
# Butter Naan                               1046.0
# Name: Qty., dtype: float64

# %%
fi.groupby("Item Name")["Qty."].sum().sort_values(ascending=False).head(3).plot(kind='bar',color="red")
# Out:
# <Axes: xlabel='Item Name'>

# %%
#revenue wise top 3 items
fi.groupby("Item Name")["Final Total"].sum().sort_values(ascending=False).head(3)
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    240730.96
# Chicken Fried Rice                        119347.20
# Butter Naan                                65387.74
# Name: Final Total, dtype: float64

# %%
#filter out only date
fi[fi["Date"]=="14.09.2023"]
# Out:
# Empty DataFrame
# Columns: [Date, Timestamp, Invoice No., Item Name, Price, Qty., Sub Total, Discount, Tax, Final Total, Table No., Server Name, Covers, Variation, Category, HSN]
# Index: []

# %%
#14/9/2023-top spent revenue num
fi.groupby("Invoice No.")["Final Total"].sum().head(1)#wrong
# Out:
# Invoice No.
# 23465    1134.0
# Name: Final Total, dtype: float64

# %%
#idenity invoice whose bill value is above the overall average bill value
#do high quantity items always generate high revenue
#which product contributes the highet percentage of total revenue?

# %%
avg=fi.groupby("Invoice No.")["Final Total"].sum().mean()

# %%
(fi.groupby("Invoice No.")["Final Total"].sum()>fi.groupby("Invoice No.")["Final Total"].sum().mean()).sum()
# Out:
# np.int64(1458)

# %%
fi.groupby("Item Name")[["Qty.","Final Total"]].sum().sort_values("Final Total", ascending=False)
# Out:
#                                           Qty.  Final Total
# Item Name
# Chicken Biriyani With Raitha And Gravy  1453.0    240730.96
# Chicken Fried Rice                       716.0    119347.20
# Butter Naan                             1046.0     65387.74
# Thandoor Chicken Half                    256.0     53185.83
# Paneer Butter Masala                     321.0     49581.22
# ...                                        ...          ...
# Tomato Soup                                1.0        84.00
# Veg Kothu Parata                           1.0        73.50
# Water Bottle 500 Ml                        5.0        63.00
# Vechhu Paratha (1 No)                      1.0        52.50
# Soft Drinks Tin                            1.0        42.00
#
# [270 rows x 2 columns]

# %%
((fi.groupby("Item Name")["Final Total"].sum() / fi["Final Total"].sum()) * 100).sort_values(ascending=False).head(1)
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    10.042968
# Name: Final Total, dtype: float64
